# %% [markdown]
# ### OPERATORNORM WITHOUT ADJOINT
#
# - Creator:  Jonas Bresch, M.Sc
# - Date: February 14rd, 2025

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy as sc

import imp
# Out:
# /var/folders/x8/2j6ym0tn7x18f9h9pmv136mc0000gn/T/ipykernel_8134/852982894.py:5: DeprecationWarning: the imp module is deprecated in favour of importlib and slated for removal in Python 3.12; see the module's documentation for alternative uses
#   import imp

# %%
import adjointfreenorm
imp.reload(adjointfreenorm)
# Out:
# <module 'adjointfreenorm' from '/Users/jonasbresch/Desktop/operator_missmatch/finale/adjointfreenorm.py'>

# %% [markdown]
# ### Figure 3 - 50x50

# %%
fig, axs = plt.subplots(2, 1, figsize=(5,7), gridspec_kw={'height_ratios': [3, 1]})
plt.rc('font', family='serif')
for k in range(50):
    A = np.random.randn(50,50)
    V = np.random.randn(50,50)
    # _, _, vu_sol_o, _, _, vvvual_o, _, lista_uv_o, _ = adjointfreenorm.MatFreeAdjOpNorm(A=A, V=V, iter=2000, eps=1e-10, show=0)
    _, _, vu_sol, _, _, vuval, _, _, listbc_uv, _, _, _, _, _ = adjointfreenorm.MatFreeAdjOpNormDouble(A=A, V=V, iter=2000, eps=1e-10, show=0)
    # axs[0].plot((vu_sol_o-np.abs(vvvual_o))/vu_sol_o, linewidth=0.2, c='b')
    axs[0].plot((vu_sol-np.abs(vuval))/vu_sol, linewidth=0.2, c='orange')
    axs[0].semilogy()
    # axs[1].plot(lista_uv_o, linewidth=0.2, c='b')
    axs[1].plot(listbc_uv, linewidth=0.2, c='orange')
    plt.setp(axs, xticks=[0, 1000, 2000], xticklabels=['0', '1000', '2000'])
    plt.rc('text', usetex=True)
plt.rc('font', family='serif')
plt.savefig('gaussian_matrices_50_50_single.pdf', dpi=100)
plt.show()
# Out:
# iter. 	| func-value 	| residuum 	| sing-vec-error
# 2000 	|  1.869e+01 	|  2.910e-04 	|  3.682e-07
# ||A|| =  18.686053219781982
# iter. 	| func-value 	| residuum 	| sing-vec-error
# 2000 	|  1.775e+01 	|  5.473e-02 	|  6.521e-05
# ||A|| =  17.753138457038556
# iter. 	| func-value 	| residuum 	| sing-vec-error
# 2000 	|  1.963e+01 	|  7.515e-02 	|  1.337e-02
# ||A|| =  19.63350830656677
# iter. 	| func-value 	| residuum 	| sing-vec-error
# 2000 	|  1.929e+01 	|  9.963e-04 	|  2.482e-03
# ||A|| =  19.286596117026836
# iter. 	| func-value 	| residuum 	| sing-vec-error
# 2000 	|  1.940e+01 	|  2.336e-03 	|  3.272e-06
# ||A|| =  19.39609701792037
# iter. 	| func-value 	| residuum 	| sing-vec-error
# 2000 	|  1.893e+01 	|  1.096e-01 	|  4.798e-05
# ||A|| =  18.933566165293286
# iter. 	| func-value 	| residuum 	| sing-vec-error
# 2000 	|  2.043e+01 	|  9.940e-04 	|  3.177e-03
# ||A|| =  20.425731650991995
# iter. 	| func-value 	| residuum 	| sing-vec-error
# 2000 	|  1.939e+01 	|  7.476e-03 	|  1.034e-02
# ||A|| =  19.39048860379279
# iter. 	| func-value 	| residuum 	| sing-vec-error
# 2000 	|  1.913e+01 	|  4.540e-04 	|  1.726e-03
# ||A|| =  19.12886915489052
# iter. 	| func-value 	| residuum 	| sing-vec-error
# 2000 	|  1.939e+01 	|  6.523e-03 	|  9.974e-06
# ||A|| =  19.38508489100648
# iter. 	| func-value 	| residuum 	| sing-vec-error
# 2000 	|  1.937e+01 	|  2.960e-01 	|  1.761e-04
# ||A|| =  19.371878894215996
# iter. 	| func-value 	| residuum 	| sing-vec-error
# 2000 	|  1.839e+01 	|  1.189e-01 	|  5.190e-05
# ||A|| =  18.388113931369087
# iter. 	| func-value 	| residuum 	| sing-vec-error
# 2000 	|  1.887e+01 	|  8.200e-01 	|  1.148e-02
# ||A|| =  18.869219196082256
# iter. 	| func-value 	| residuum 	| sing-vec-error
# 2000 	|  1.881e+01 	|  1.168e-02 	|  2.061e-05
# ||A|| =  18.810934061406126
# iter. 	| func-value 	| residuum 	| sing-vec-error
# 2000 	|  1.963e+01 	|  6.071e-02 	|  1.227e-02
# ||A|| =  19.6335069302825
# iter. 	| func-value 	| residuum 	| sing-vec-error
# 2000 	|  1.899e+01 	|  1.358e-04 	|  9.247e-04
# ||A|| =  18.993545352520904
# iter. 	| func-value 	| residuum 	| sing-vec-error
# 2000 	|  1.875e+01 	|  8.892e-03 	|  6.228e-03
# ||A|| =  18.753179686803787
# iter. 	| func-value 	| residuum 	| sing-vec-error
# 2000 	|  1.964e+01 	|  4.253e-03 	|  4.261e-06
# ||A|| =  19.642914415234912
# iter. 	| func-value 	| residuum 	| sing-vec-error
# 2000 	|  1.839e+01 	|  2.425e-01 	|  1.624e-02
# ||A|| =  18.394711994534312
# iter. 	| func-value 	| residuum 	| sing-vec-error
# 2000 	|  1.992e+01 	|  8.764e-05 	|  7.487e-04
# ||A|| =  19.923406288433448
# iter. 	| func-value 	| residuum 	| sing-vec-error
# 2000 	|  1.837e+01 	|  2.408e-02 	|  1.089e-02
# ||A|| =  18.37412096137394
# iter. 	| func-value 	| residuum 	| sing-vec-error
# 2000 	|  1.863e+01 	|  9.129e-02 	|  2.283e-02
# ||A|| =  18.631077944639372
# iter. 	| func-value 	| residuum 	| sing-vec-error
# 2000 	|  1.797e+01 	|  9.774e-01 	|  3.354e-02
# ||A|| =  17.967335790079332
# iter. 	| func-value 	| residuum 	| sing-vec-error
# 2000 	|  1.997e+01 	|  2.540e-03 	|  6.813e-06
# ||A|| =  19.966493170933134
# iter. 	| func-value 	| residuum 	| sing-vec-error
# 2000 	|  1.839e+01 	|  3.445e-01 	|  2.658e-04
# ||A|| =  18.386116522506825
# iter. 	| func-value 	| residuum 	| sing-vec-error
# 2000 	|  1.982e+01 	|  4.674e-04 	|  2.174e-03
# ||A|| =  19.819713668348804
# iter. 	| func-value 	| residuum 	| sing-vec-error
# 2000 	|  1.839e+01 	|  1.253e+00 	|  3.031e-02
# ||A|| =  18.39211699255783
# iter. 	| func-value 	| residuum 	| sing-vec-error
# 2000 	|  2.076e+01 	|  7.195e-05 	|  9.296e-04
# ||A|| =  20.760141497561516
# iter. 	| func-value 	| residuum 	| sing-vec-error
# 2000 	|  1.940e+01 	|  3.149e-02 	|  1.760e-05
# ||A|| =  19.396207789179243
# iter. 	| func-value 	| residuum 	| sing-vec-error
# 2000 	|  1.978e+01 	|  9.414e-05 	|  7.940e-04
# ||A|| =  19.775549013562603
# iter. 	| func-value 	| residuum 	| sing-vec-error
# 2000 	|  1.966e+01 	|  1.948e-01 	|  1.132e-04
# ||A|| =  19.663313849606045
# iter. 	| func-value 	| residuum 	| sing-vec-error
# 2000 	|  1.888e+01 	|  5.736e-02 	|  5.954e-05
# ||A|| =  18.87694264044868
# iter. 	| func-value 	| residuum 	| sing-vec-error
# 2000 	|  1.992e+01 	|  5.248e-03 	|  8.369e-03
# ||A|| =  19.919666591620807
# iter. 	| func-value 	| residuum 	| sing-vec-error
# 2000 	|  1.908e+01 	|  6.635e-06 	|  1.809e-08
# ||A|| =  19.08358154396035
# iter. 	| func-value 	| residuum 	| sing-vec-error
# 2000 	|  2.031e+01 	|  3.127e-03 	|  4.805e-03
# ||A|| =  20.30797830247852
# iter. 	| func-value 	| residuum 	| sing-vec-error
# 2000 	|  1.930e+01 	|  3.975e-01 	|  1.225e-04
# ||A|| =  19.29824204805937
# iter. 	| func-value 	| residuum 	| sing-vec-error
# 2000 	|  1.844e+01 	|  3.846e-02 	|  2.183e-05
# ||A|| =  18.440547437673366
# iter. 	| func-value 	| residuum 	| sing-vec-error
# 2000 	|  1.881e+01 	|  9.584e-03 	|  8.386e-03
# ||A|| =  18.813032620504785
# iter. 	| func-value 	| residuum 	| sing-vec-error
# 2000 	|  1.988e+01 	|  1.260e-02 	|  6.126e-03
# ||A|| =  19.88289021794394
# iter. 	| func-value 	| residuum 	| sing-vec-error
# 2000 	|  1.948e+01 	|  1.697e-02 	|  1.134e-02
# ||A|| =  19.47534844364064
# iter. 	| func-value 	| residuum 	| sing-vec-error
# 2000 	|  1.901e+01 	|  6.682e-03 	|  5.128e-03
# ||A|| =  19.00562444227451
# iter. 	| func-value 	| residuum 	| sing-vec-error
# 2000 	|  1.978e+01 	|  2.881e-03 	|  6.101e-06
# ||A|| =  19.775421838678255
# iter. 	| func-value 	| residuum 	| sing-vec-error
# 2000 	|  1.873e+01 	|  4.692e-02 	|  1.008e-04
# ||A|| =  18.733174029220883
# iter. 	| func-value 	| residuum 	| sing-vec-error
# 2000 	|  1.940e+01 	|  1.460e-02 	|  3.701e-05
# ||A|| =  19.404624879942823
# iter. 	| func-value 	| residuum 	| sing-vec-error
# 2000 	|  2.036e+01 	|  1.676e-03 	|  5.701e-06
# ||A|| =  20.35829234496471
# iter. 	| func-value 	| residuum 	| sing-vec-error
# 2000 	|  1.937e+01 	|  1.358e-03 	|  3.091e-03
# ||A|| =  19.36893539771713
# iter. 	| func-value 	| residuum 	| sing-vec-error
# 2000 	|  1.838e+01 	|  5.203e-02 	|  1.647e-02
# ||A|| =  18.378765469883376
# iter. 	| func-value 	| residuum 	| sing-vec-error
# 2000 	|  1.996e+01 	|  3.551e-06 	|  9.278e-09
# ||A|| =  19.962708257628172
# iter. 	| func-value 	| residuum 	| sing-vec-error
# 2000 	|  1.834e+01 	|  1.593e-03 	|  1.639e-06
# ||A|| =  18.34402228859719
# iter. 	| func-value 	| residuum 	| sing-vec-error
# 2000 	|  1.915e+01 	|  7.264e-03 	|  6.826e-03
# ||A|| =  19.15026219057402
