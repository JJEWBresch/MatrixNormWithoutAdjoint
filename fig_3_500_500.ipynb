# %% [markdown]
# ### OPERATORNORM WITHOUT ADJOINT
#
# - Creator:  Jonas Bresch, M.Sc
# - Date: February 14rd, 2025

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy as sc

import imp
# Out:
# /var/folders/x8/2j6ym0tn7x18f9h9pmv136mc0000gn/T/ipykernel_8310/852982894.py:5: DeprecationWarning: the imp module is deprecated in favour of importlib and slated for removal in Python 3.12; see the module's documentation for alternative uses
#   import imp

# %%
import adjointfreenorm
imp.reload(adjointfreenorm)
# Out:
# <module 'adjointfreenorm' from '/Users/jonasbresch/Desktop/operator_missmatch/finale/adjointfreenorm.py'>

# %% [markdown]
# ### Figure 3 - 500x500

# %%
fig, axs = plt.subplots(2, 1, figsize=(5,7), gridspec_kw={'height_ratios': [3, 1]})
plt.rc('font', family='serif')
for k in range(50):
    A = np.random.randn(500,500)
    V = np.random.randn(500,500)
    # _, _, vu_sol_o, _, _, vvvual_o, _, lista_uv_o, _ = adjointfreenorm.MatFreeAdjOpNorm(A=A, V=V, iter=10000, eps=1e-10, show=0)
    _, _, vu_sol, _, _, vuval, _, _, listbc_uv, _, _, _, _, _ = adjointfreenorm.MatFreeAdjOpNormDouble(A=A, V=V, iter=10000, eps=1e-10, show=0)
    # axs[0].plot((vu_sol_o-np.abs(vvvual_o))/vu_sol_o, linewidth=0.2, c='b')
    axs[0].plot((vu_sol-np.abs(vuval))/vu_sol, linewidth=0.2, c='orange')
    axs[0].semilogy()
    # axs[1].plot(lista_uv_o, linewidth=0.2, c='b')
    axs[1].plot(listbc_uv, linewidth=0.2, c='orange')
    plt.setp(axs, xticks=[0, 5000, 10000], xticklabels=['0', '5000', '10000'])
    plt.rc('text', usetex=True)
plt.rc('font', family='serif')
plt.savefig('gaussian_matrices_500_500_single.pdf', dpi=100)
plt.show()
# Out:
# iter. 	| func-value 	| residuum 	| sing-vec-error
# 10000 	|  6.009e+01 	|  2.489e+00 	|  5.827e-04
# ||A|| =  60.08668407471402
# iter. 	| func-value 	| residuum 	| sing-vec-error
# 10000 	|  6.090e+01 	|  1.749e+00 	|  4.234e-04
# ||A|| =  60.900326185461395
# iter. 	| func-value 	| residuum 	| sing-vec-error
# 10000 	|  5.963e+01 	|  2.733e+00 	|  3.698e-02
# ||A|| =  59.63331824937046
# iter. 	| func-value 	| residuum 	| sing-vec-error
# 10000 	|  6.098e+01 	|  1.382e+00 	|  3.376e-02
# ||A|| =  60.97969022204995
# iter. 	| func-value 	| residuum 	| sing-vec-error
# 10000 	|  5.972e+01 	|  2.493e+00 	|  3.447e-02
# ||A|| =  59.723780030172264
# iter. 	| func-value 	| residuum 	| sing-vec-error
# 10000 	|  6.084e+01 	|  1.420e+00 	|  3.162e-04
# ||A|| =  60.84026553885489
# iter. 	| func-value 	| residuum 	| sing-vec-error
# 10000 	|  6.167e+01 	|  1.172e+00 	|  2.811e-02
# ||A|| =  61.67482419119872
# iter. 	| func-value 	| residuum 	| sing-vec-error
# 10000 	|  6.172e+01 	|  1.563e+00 	|  3.427e-02
# ||A|| =  61.719291049206056
# iter. 	| func-value 	| residuum 	| sing-vec-error
# 10000 	|  6.231e+01 	|  4.902e-01 	|  3.009e-02
# ||A|| =  62.31061224668352
# iter. 	| func-value 	| residuum 	| sing-vec-error
# 10000 	|  6.078e+01 	|  1.827e+00 	|  4.290e-02
# ||A|| =  60.784437149320574
# iter. 	| func-value 	| residuum 	| sing-vec-error
# 10000 	|  6.012e+01 	|  2.401e+00 	|  3.146e-04
# ||A|| =  60.12180513533851
# iter. 	| func-value 	| residuum 	| sing-vec-error
# 10000 	|  6.009e+01 	|  2.788e+00 	|  4.050e-02
# ||A|| =  60.09360044840593
# iter. 	| func-value 	| residuum 	| sing-vec-error
# 10000 	|  6.093e+01 	|  9.791e-01 	|  2.949e-02
# ||A|| =  60.925102124584484
# iter. 	| func-value 	| residuum 	| sing-vec-error
# 10000 	|  6.131e+01 	|  1.106e+00 	|  3.519e-04
# ||A|| =  61.31272540207185
# iter. 	| func-value 	| residuum 	| sing-vec-error
# 10000 	|  6.103e+01 	|  1.868e+00 	|  3.951e-02
# ||A|| =  61.033180479278315
# iter. 	| func-value 	| residuum 	| sing-vec-error
# 10000 	|  6.151e+01 	|  9.526e-01 	|  2.741e-04
# ||A|| =  61.50830448770162
# iter. 	| func-value 	| residuum 	| sing-vec-error
# 10000 	|  6.225e+01 	|  6.739e-01 	|  2.808e-04
# ||A|| =  62.247686987133854
# iter. 	| func-value 	| residuum 	| sing-vec-error
# 10000 	|  5.957e+01 	|  2.690e+00 	|  2.718e-04
# ||A|| =  59.56592663039323
# iter. 	| func-value 	| residuum 	| sing-vec-error
# 10000 	|  6.132e+01 	|  1.635e+00 	|  5.661e-04
# ||A|| =  61.32220215798168
# iter. 	| func-value 	| residuum 	| sing-vec-error
# 10000 	|  6.081e+01 	|  1.544e+00 	|  3.579e-02
# ||A|| =  60.807372282579045
# iter. 	| func-value 	| residuum 	| sing-vec-error
# 10000 	|  6.123e+01 	|  8.595e-01 	|  3.421e-02
# ||A|| =  61.23240908036892
# iter. 	| func-value 	| residuum 	| sing-vec-error
# 10000 	|  6.139e+01 	|  1.234e+00 	|  3.839e-04
# ||A|| =  61.39132314225529
# iter. 	| func-value 	| residuum 	| sing-vec-error
# 10000 	|  6.051e+01 	|  2.506e+00 	|  4.145e-04
# ||A|| =  60.50758000150601
# iter. 	| func-value 	| residuum 	| sing-vec-error
# 10000 	|  6.039e+01 	|  2.473e+00 	|  4.930e-02
# ||A|| =  60.39458548078043
# iter. 	| func-value 	| residuum 	| sing-vec-error
# 10000 	|  6.060e+01 	|  1.940e+00 	|  3.257e-02
# ||A|| =  60.59782462052753
# iter. 	| func-value 	| residuum 	| sing-vec-error
# 10000 	|  6.037e+01 	|  3.080e+00 	|  2.164e-04
# ||A|| =  60.36793402021256
# iter. 	| func-value 	| residuum 	| sing-vec-error
# 10000 	|  6.205e+01 	|  8.240e-01 	|  3.450e-02
# ||A|| =  62.05453740970685
# iter. 	| func-value 	| residuum 	| sing-vec-error
# 10000 	|  6.019e+01 	|  2.201e+00 	|  3.105e-04
# ||A|| =  60.18680945083709
# iter. 	| func-value 	| residuum 	| sing-vec-error
# 10000 	|  6.031e+01 	|  2.584e+00 	|  4.370e-02
# ||A|| =  60.30747934491973
# iter. 	| func-value 	| residuum 	| sing-vec-error
# 10000 	|  6.103e+01 	|  2.214e+00 	|  3.334e-04
# ||A|| =  61.027133230186934
# iter. 	| func-value 	| residuum 	| sing-vec-error
# 10000 	|  6.062e+01 	|  1.999e+00 	|  3.809e-02
# ||A|| =  60.624140010113976
# iter. 	| func-value 	| residuum 	| sing-vec-error
# 10000 	|  6.157e+01 	|  1.031e+00 	|  2.024e-04
# ||A|| =  61.57352952395527
# iter. 	| func-value 	| residuum 	| sing-vec-error
# 10000 	|  6.164e+01 	|  1.414e+00 	|  3.831e-02
# ||A|| =  61.644813746815856
# iter. 	| func-value 	| residuum 	| sing-vec-error
# 10000 	|  6.159e+01 	|  1.847e+00 	|  4.414e-02
# ||A|| =  61.58576463838811
# iter. 	| func-value 	| residuum 	| sing-vec-error
# 10000 	|  6.120e+01 	|  1.389e+00 	|  2.616e-04
# ||A|| =  61.20256738710788
# iter. 	| func-value 	| residuum 	| sing-vec-error
# 10000 	|  6.180e+01 	|  6.476e-01 	|  2.764e-02
# ||A|| =  61.80170705582009
# iter. 	| func-value 	| residuum 	| sing-vec-error
# 10000 	|  6.236e+01 	|  4.897e-01 	|  2.962e-02
# ||A|| =  62.36327636472412
# iter. 	| func-value 	| residuum 	| sing-vec-error
# 10000 	|  6.072e+01 	|  1.539e+00 	|  4.232e-04
# ||A|| =  60.71776220084254
# iter. 	| func-value 	| residuum 	| sing-vec-error
# 10000 	|  5.926e+01 	|  3.548e+00 	|  4.679e-02
# ||A|| =  59.25712413322064
# iter. 	| func-value 	| residuum 	| sing-vec-error
# 10000 	|  6.090e+01 	|  2.138e+00 	|  2.970e-04
# ||A|| =  60.902589669148966
# iter. 	| func-value 	| residuum 	| sing-vec-error
# 10000 	|  6.096e+01 	|  2.654e+00 	|  3.908e-02
# ||A|| =  60.95589827640219
# iter. 	| func-value 	| residuum 	| sing-vec-error
# 10000 	|  6.149e+01 	|  1.085e+00 	|  3.554e-02
# ||A|| =  61.48905918913108
# iter. 	| func-value 	| residuum 	| sing-vec-error
# 10000 	|  6.171e+01 	|  1.544e+00 	|  4.058e-02
# ||A|| =  61.70533534718608
# iter. 	| func-value 	| residuum 	| sing-vec-error
# 10000 	|  6.087e+01 	|  2.045e+00 	|  2.082e-04
# ||A|| =  60.86632756272495
# iter. 	| func-value 	| residuum 	| sing-vec-error
# 10000 	|  6.069e+01 	|  1.644e+00 	|  4.035e-02
# ||A|| =  60.687450706719176
# iter. 	| func-value 	| residuum 	| sing-vec-error
# 10000 	|  6.001e+01 	|  2.310e+00 	|  2.652e-04
# ||A|| =  60.01208447582817
# iter. 	| func-value 	| residuum 	| sing-vec-error
# 10000 	|  5.987e+01 	|  2.301e+00 	|  4.170e-02
# ||A|| =  59.86839188800248
# iter. 	| func-value 	| residuum 	| sing-vec-error
# 10000 	|  6.080e+01 	|  2.137e+00 	|  2.204e-04
# ||A|| =  60.80167726703819
# iter. 	| func-value 	| residuum 	| sing-vec-error
# 10000 	|  6.130e+01 	|  1.305e+00 	|  2.884e-04
# ||A|| =  61.29944954371653
# iter. 	| func-value 	| residuum 	| sing-vec-error
# 10000 	|  6.133e+01 	|  1.901e+00 	|  2.888e-04
# ||A|| =  61.33387598053136
