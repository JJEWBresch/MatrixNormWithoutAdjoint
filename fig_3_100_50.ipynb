# %% [markdown]
# ### OPERATORNORM WITHOUT ADJOINT
#
# - Creator:  Jonas Bresch, M.Sc
# - Date: February 14rd, 2025

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy as sc

import imp
# Out:
# /var/folders/x8/2j6ym0tn7x18f9h9pmv136mc0000gn/T/ipykernel_44408/852982894.py:5: DeprecationWarning: the imp module is deprecated in favour of importlib and slated for removal in Python 3.12; see the module's documentation for alternative uses
#   import imp

# %%
import adjointfreenorm
imp.reload(adjointfreenorm)
# Out:
# <module 'adjointfreenorm' from '/Users/jonasbresch/Desktop/operator_missmatch/finale/adjointfreenorm.py'>

# %% [markdown]
# ### Figure 3 - 100x50

# %%
fig, axs = plt.subplots(3, 1, figsize=(5,10), gridspec_kw={'height_ratios': [3, 1, 1]})
for k in range(50):
    A = np.random.randn(100,50)
    V = np.random.randn(50,100)
    _, _, vu_sol_o, _, _, vvvual_o, _, lista_uv_o, _ = adjointfreenorm.MatFreeAdjOpNorm(A=A, V=V, iter=2000, eps=1e-10, show=0)
    _, _, vu_sol, _, _, vuval, _, _, listbc_uv, _, _, _, _, _ = adjointfreenorm.MatFreeAdjOpNormDouble(A=A, V=V, iter=2000, eps=1e-10, show=0)
    axs[0].plot((vu_sol_o-np.abs(vvvual_o))/vu_sol_o, linewidth=0.2, c='b')
    axs[0].plot((vu_sol-np.abs(vuval))/vu_sol, linewidth=0.2, c='orange')
    axs[0].semilogy()
    axs[1].plot(lista_uv_o, linewidth=0.2, c='b')
    axs[2].plot(listbc_uv, linewidth=0.2, c='orange')
    plt.setp(axs, xticks=[0, 1000, 2000], xticklabels=['0', '1000', '2000'])
    plt.rc('text', usetex=True)
plt.rc('font', family='serif')
plt.savefig('gaussian_matrices_100_50.pdf', dpi=100)
plt.show()
# Out:
# iter 	| func-value 	| residuum  	| sing-vec-error
# 2000 	|  2.451e+01 	|  5.038e-01 	|  9.397e-02
# ||A|| =  24.50838366251152
# iter. 	| func-value 	| residuum 	| sing-vec-error
# 2000 	|  2.501e+01 	|  2.647e-03 	|  1.311e-05
# ||A|| =  25.009522219454905
# /usr/local/lib/python3.11/site-packages/matplotlib/cbook/__init__.py:1335: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)
# iter 	| func-value 	| residuum  	| sing-vec-error
# 2000 	|  2.202e+01 	|  1.167e+00 	|  6.931e-02
# ||A|| =  22.022761613252186
# iter. 	| func-value 	| residuum 	| sing-vec-error
# 2000 	|  2.281e+01 	|  3.794e-01 	|  3.969e-04
# ||A|| =  22.81078930737824
# iter 	| func-value 	| residuum  	| sing-vec-error
# 2000 	|  2.262e+01 	|  1.020e+00 	|  8.001e-02
# ||A|| =  22.616211777576364
# iter. 	| func-value 	| residuum 	| sing-vec-error
# 2000 	|  2.322e+01 	|  4.167e-01 	|  5.615e-04
# ||A|| =  23.219517448852546
# iter 	| func-value 	| residuum  	| sing-vec-error
# 2000 	|  2.218e+01 	|  8.538e-01 	|  5.055e-02
# ||A|| =  22.182453256557814
# iter. 	| func-value 	| residuum 	| sing-vec-error
# 2000 	|  2.262e+01 	|  4.124e-01 	|  8.055e-04
# ||A|| =  22.623841643436073
# iter 	| func-value 	| residuum  	| sing-vec-error
# 2000 	|  2.362e+01 	|  5.807e-01 	|  7.893e-02
# ||A|| =  23.62209227273648
# iter. 	| func-value 	| residuum 	| sing-vec-error
# 2000 	|  2.420e+01 	|  6.445e-03 	|  1.609e-05
# ||A|| =  24.196347083396976
# iter 	| func-value 	| residuum  	| sing-vec-error
# 2000 	|  2.199e+01 	|  4.983e-01 	|  3.329e-02
# ||A|| =  21.993418597342917
# iter. 	| func-value 	| residuum 	| sing-vec-error
# 2000 	|  2.229e+01 	|  2.043e-01 	|  3.015e-02
# ||A|| =  22.287361855226457
# iter 	| func-value 	| residuum  	| sing-vec-error
# 2000 	|  2.163e+01 	|  1.143e+00 	|  5.998e-02
# ||A|| =  21.63215344852692
# iter. 	| func-value 	| residuum 	| sing-vec-error
# 2000 	|  2.232e+01 	|  4.582e-01 	|  1.853e-02
# ||A|| =  22.31660326256096
# iter 	| func-value 	| residuum  	| sing-vec-error
# 2000 	|  2.468e+01 	|  2.971e-01 	|  7.928e-02
# ||A|| =  24.677927173614066
# iter. 	| func-value 	| residuum 	| sing-vec-error
# 2000 	|  2.365e+01 	|  1.324e+00 	|  8.662e-02
# ||A|| =  23.650762115650213
# iter 	| func-value 	| residuum  	| sing-vec-error
# 2000 	|  2.226e+01 	|  7.692e-01 	|  5.783e-02
# ||A|| =  22.259024573920314
# iter. 	| func-value 	| residuum 	| sing-vec-error
# 2000 	|  2.303e+01 	|  3.133e-03 	|  7.827e-06
# ||A|| =  23.025099393017516
# iter 	| func-value 	| residuum  	| sing-vec-error
# 2000 	|  2.237e+01 	|  6.975e-01 	|  7.562e-02
# ||A|| =  22.37042785948016
# iter. 	| func-value 	| residuum 	| sing-vec-error
# 2000 	|  2.267e+01 	|  3.948e-01 	|  5.789e-02
# ||A|| =  22.673115668001216
# iter 	| func-value 	| residuum  	| sing-vec-error
# 2000 	|  2.176e+01 	|  4.215e-01 	|  5.522e-02
# ||A|| =  21.758289844957147
# iter. 	| func-value 	| residuum 	| sing-vec-error
# 2000 	|  2.194e+01 	|  2.405e-01 	|  1.701e-04
# ||A|| =  21.93927627820476
# iter 	| func-value 	| residuum  	| sing-vec-error
# 2000 	|  2
# iter 	| func-value 	| residuum  	| sing-vec-error
# 2000 	|  2.179e+01 	|  2.083e+00 	|  5.219e-02
# ||A|| =  21.79162427301131
# iter. 	| func-value 	| residuum 	| sing-vec-error
# 2000 	|  2.315e+01 	|  7.211e-01 	|  5.952e-02
# ||A|| =  23.153778070378703
# iter 	| func-value 	| residuum  	| sing-vec-error
# 2000 	|  2.218e+01 	|  8.082e-01 	|  6.652e-02
# ||A|| =  22.183650887909074
# iter. 	| func-value 	| residuum 	| sing-vec-error
# 2000 	|  2.259e+01 	|  3.970e-01 	|  4.303e-02
# ||A|| =  22.594802277881396
# iter 	| func-value 	| residuum  	| sing-vec-error
# 2000 	|  2.460e+01 	|  1.965e-01 	|  6.314e-02
# ||A|| =  24.597908826876996
# iter. 	| func-value 	| residuum 	| sing-vec-error
# 2000 	|  2.479e+01 	|  1.091e-04 	|  1.657e-03
# ||A|| =  24.79429398698563
# iter 	| func-value 	| residuum  	| sing-vec-error
# 2000 	|  2.302e+01 	|  1.062e+00 	|  1.067e-01
# ||A|| =  23.020765011842265
# iter. 	| func-value 	| residuum 	| sing-vec-error
# 2000 	|  2.408e+01 	|  6.832e-03 	|  2.305e-05
# ||A|| =  24.076026569425437
# iter 	| func-value 	| residuum  	| sing-vec-error
# 2000 	|  2.439e+01 	|  1.534e-01 	|  4.114e-02
# ||A|| =  24.392026843747047
# iter. 	| func-value 	| residuum 	| sing-vec-error
# 2000 	|  2.454e+01 	|  6.423e-03 	|  2.390e-05
# ||A|| =  24.538986434789038
# iter 	| func-value 	| residuum  	| sing-vec-error
# 2000 	|  2.167e+01 	|  1.254e+00 	|  5.809e-02
# ||A|| =  21.668474512291866
# iter. 	| func-value 	| residuum 	| sing-vec-error
# 2000 	|  2.291e+01 	|  9.714e-03 	|  9.533e-03
# ||A|| =  22.912564844527445
# iter 	| func-value 	| residuum  	| sing-vec-error
# 2000 	|  2.385e+01 	|  4.328e-01 	|  5.543e-02
# ||A|| =  23.84902084928386
# iter. 	| func-value 	| residuum 	| sing-vec-error
# 2000 	|  2.353e+01 	|  7.494e-01 	|  7.637e-04
# ||A|| =  23.53240519200007
# iter 	| func-value 	| residuum  	| sing-vec-error
# 2000 	|  2.265e+01 	|  4.187e-01 	|  6.353e-02
# ||A|| =  22.649224994583623
# iter. 	| func-value 	| residuum 	| sing-vec-error
# 2000 	|  2.277e+01 	|  2.947e-01 	|  4.447e-02
# ||A|| =  22.77331158028641
# iter 	| func-value 	| residuum  	| sing-vec-error
# 2000 	|  2.211e+01 	|  7.878e-01 	|  3.858e-02
# ||A|| =  22.10670593894224
# iter. 	| func-value 	| residuum 	| sing-vec-error
# 2000 	|  2.228e+01 	|  6.172e-01 	|  3.810e-02
# ||A|| =  22.277308149729137
# iter 	| func-value 	| residuum  	| sing-vec-error
# 2000 	|  2.210e+01 	|  1.066e+00 	|  7.085e-02
# ||A|| =  22.10247747272816
# iter. 	| func-value 	| residuum 	| sing-vec-error
# 2000 	|  2.314e+01 	|  2.381e-02 	|  6.516e-05
# ||A|| =  23.144567216729
# iter 	| func-value 	| residuum  	| sing-vec-error
# 2000 	|  2.234e+01 	|  1.086e+00 	|  6.118e-02
# ||A|| =  22.340405652506078
# iter. 	| func-value 	| residuum 	| sing-vec-error
# 2000 	|  2.340e+01 	|  2.559e-02 	|  6.032e-05
# ||A|| =  23.401191909219833
# iter 	| func-value 	| residuum  	| sing-vec-error
# 2000 	|  2.156e+01 	|  8.496e-01 	|  7.431e-02
# ||A|| =  21.562731465195505
# iter. 	| func-value 	| residuum 	| sing-vec-error
# 2000 	|  2.227e+01 	|  1.423e-01 	|  2.822e-04
# ||A|| =  22.270067108653038
# iter 	| func-value 	| residuum  	| sing-vec-error
# 2000 	|  2.294e+01 	|  2.425e-01 	|  5.725e-02
# ||A|| =  22.93991589500768
# iter. 	| func-value 	| residuum 	| sing-vec-error
# 2000 	|  2.239e+01 	|  7.896e-01 	|  1.691e-03
# ||A|| =  22.392831384635585
# iter 	| func-value 	| residuum  	| sing-vec-error
# 2000 	|  2.191e+01 	|  1.318e+00 	|  9.844e-02
# ||A|| =  21.910705406024253
# iter. 	| func-value 	| residuum 	| sing-vec-error
# 2000 	|  2.307e+01 	|  1.632e-01 	|  3.638e-02
# ||A|| =  23.065954420454716
# iter 	| func-value 	| residuum  	| sing-vec-error
# 2000 	|  2.296e+01 	|  1.285e-01 	|  3.961e-02
# ||A|| =  22.957669216632738
# iter. 	| func-value 	| residuum 	| sing-vec-error
# 2000 	|  2.305e+01 	|  3.828e-02 	|  5.647e-05
# ||A|| =  23.04787318847726
# iter 	| func-value 	| residuum  	| sing-vec-error
# 2000 	|  2.374e+01 	|  3.000e-01 	|  6.315e-02
# ||A|| =  23.742971998117632
# iter. 	| func-value 	| residuum 	| sing-vec-error
# 2000 	|  2.391e+01 	|  1.297e-01 	|  3.011e-04
# ||A|| =  23.91325090972078
# iter 	| func-value 	| residuum  	| sing-vec-error
# 2000 	|  2.333e+01 	|  3.508e-01 	|  4.246e-02
# ||A|| =  23.332513949358134
# iter. 	| func-value 	| residuum 	| sing-vec-error
# 2000 	|  2.316e+01 	|  5.207e-01 	|  2.653e-04
# ||A|| =  23.162603801640216
# iter 	| func-value 	| residuum  	| sing-vec-error
# 2000 	|  2.372e+01 	|  3.715e-01 	|  7.048e-02
# ||A|| =  23.721499601593287
# iter. 	| func-value 	| residuum 	| sing-vec-error
# 2000 	|  2.391e+01 	|  1.786e-01 	|  3.849e-04
# ||A|| =  23.91447485702637
# iter 	| func-value 	| residuum  	| sing-vec-error
# 2000 	|  2.196e+01 	|  9.638e-01 	|  8.046e-02
# ||A|| =  21.962187148499595
# iter. 	| func-value 	| residuum 	| sing-vec-error
# 2000 	|  2.270e+01 	|  2.257e-01 	|  2.663e-02
# ||A|| =  22.700244519364965
