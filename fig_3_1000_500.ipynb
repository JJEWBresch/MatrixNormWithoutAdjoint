# %% [markdown]
# ### OPERATORNORM WITHOUT ADJOINT
#
# - Creator:  Jonas Bresch, M.Sc
# - Date: February 14rd, 2025

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy as sc

import imp
# Out:
# /var/folders/x8/2j6ym0tn7x18f9h9pmv136mc0000gn/T/ipykernel_8326/852982894.py:5: DeprecationWarning: the imp module is deprecated in favour of importlib and slated for removal in Python 3.12; see the module's documentation for alternative uses
#   import imp

# %%
import adjointfreenorm
imp.reload(adjointfreenorm)
# Out:
# <module 'adjointfreenorm' from '/Users/jonasbresch/Desktop/operator_missmatch/finale/adjointfreenorm.py'>

# %% [markdown]
# ### Figure 3 - 1000x500

# %%
fig, axs = plt.subplots(2, 1, figsize=(5,7), gridspec_kw={'height_ratios': [3, 1]})
plt.rc('font', family='serif')
for k in range(50):
    A = np.random.randn(1000,500)
    V = np.random.randn(500,1000)
    # _, _, vu_sol_o, _, _, vvvual_o, _, lista_uv_o, _ = adjointfreenorm.MatFreeAdjOpNorm(A=A, V=V, iter=10000, eps=1e-10, show=0)
    _, _, vu_sol, _, _, vuval, _, _, listbc_uv, _, _, _, _, _ = adjointfreenorm.MatFreeAdjOpNormDouble(A=A, V=V, iter=10000, eps=1e-10, show=0)
    # axs[0].plot((vu_sol_o-np.abs(vvvual_o))/vu_sol_o, linewidth=0.2, c='b')
    axs[0].plot((vu_sol-np.abs(vuval))/vu_sol, linewidth=0.2, c='orange')
    axs[0].semilogy()
    # axs[1].plot(lista_uv_o, linewidth=0.2, c='b')
    axs[1].plot(listbc_uv, linewidth=0.2, c='orange')
    plt.setp(axs, xticks=[0, 5000, 10000], xticklabels=['0', '5000', '10000'])
    plt.rc('text', usetex=True)
plt.rc('font', family='serif')
plt.savefig('gaussian_matrices_1000_500_single.pdf', dpi=100)
plt.show()
# Out:
# iter. 	| func-value 	| residuum 	| sing-vec-error
# 10000 	|  7.268e+01 	|  2.732e+00 	|  8.472e-02
# ||A|| =  72.68365145998555
# iter. 	| func-value 	| residuum 	| sing-vec-error
# 10000 	|  7.256e+01 	|  3.184e+00 	|  7.798e-02
# ||A|| =  72.56085981256449
# iter. 	| func-value 	| residuum 	| sing-vec-error
# 10000 	|  7.448e+01 	|  2.152e+00 	|  1.341e-03
# ||A|| =  74.48138208230552
# iter. 	| func-value 	| residuum 	| sing-vec-error
# 10000 	|  7.351e+01 	|  1.813e+00 	|  6.851e-02
# ||A|| =  73.50783105337567
# iter. 	| func-value 	| residuum 	| sing-vec-error
# 10000 	|  7.421e+01 	|  2.359e+00 	|  1.930e-03
# ||A|| =  74.20658876925185
# iter. 	| func-value 	| residuum 	| sing-vec-error
# 10000 	|  7.248e+01 	|  3.697e+00 	|  1.200e-03
# ||A|| =  72.48426251488672
# iter. 	| func-value 	| residuum 	| sing-vec-error
# 10000 	|  7.248e+01 	|  3.233e+00 	|  6.542e-02
# ||A|| =  72.47849723460766
# iter. 	| func-value 	| residuum 	| sing-vec-error
# 10000 	|  7.348e+01 	|  2.699e+00 	|  9.043e-02
# ||A|| =  73.4839996694656
# iter. 	| func-value 	| residuum 	| sing-vec-error
# 10000 	|  7.343e+01 	|  2.340e+00 	|  8.055e-02
# ||A|| =  73.43016085221501
# iter. 	| func-value 	| residuum 	| sing-vec-error
# 10000 	|  7.237e+01 	|  3.544e+00 	|  7.258e-02
# ||A|| =  72.37453301547367
# iter. 	| func-value 	| residuum 	| sing-vec-error
# 10000 	|  7.404e+01 	|  2.735e+00 	|  1.512e-03
# ||A|| =  74.03729656702126
# iter. 	| func-value 	| residuum 	| sing-vec-error
# 10000 	|  7.232e+01 	|  3.411e+00 	|  1.169e-03
# ||A|| =  72.31887544858688
# iter. 	| func-value 	| residuum 	| sing-vec-error
# 10000 	|  7.331e+01 	|  2.623e+00 	|  7.540e-02
# ||A|| =  73.31232918409351
# iter. 	| func-value 	| residuum 	| sing-vec-error
# 10000 	|  7.245e+01 	|  3.622e+00 	|  1.128e-03
# ||A|| =  72.44899291245848
# iter. 	| func-value 	| residuum 	| sing-vec-error
# 10000 	|  7.255e+01 	|  2.818e+00 	|  7.539e-02
# ||A|| =  72.54601911171392
# iter. 	| func-value 	| residuum 	| sing-vec-error
# 10000 	|  7.431e+01 	|  1.748e+00 	|  1.035e-03
# ||A|| =  74.31411108467083
# iter. 	| func-value 	| residuum 	| sing-vec-error
# 10000 	|  7